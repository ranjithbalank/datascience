# %%
from matplotlib import pyplot as plt
from datetime import datetime,timedelta
import pandas as pd
from matplotlib import dates as mpl_dates

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

# %%
plt.plot_date(dates,y)
plt.tight_layout()
plt.show()

# %%
plt.plot_date(dates,y,linestyle='solid')
plt.tight_layout()
plt.show()

# %%
plt.plot_date(dates,y,linestyle="solid",marker="None")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ranjithbalan\AppData\Local\Temp\ipykernel_17616\2287132371.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(dates,y,linestyle="solid",marker="None")

# %%
plt.plot_date(dates,y,linestyle="--",marker="None")
plt.gcf().autofmt_xdate()

plt.show()
# Out:
# C:\Users\Ranjithbalan\AppData\Local\Temp\ipykernel_17616\3946565116.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(dates,y,linestyle="--",marker="None")

# %%
plt.plot_date(dates,y,linestyle='--')
plt.gcf().autofmt_xdate()
date_f=mpl_dates.DateFormatter("%b, %d ,%Y")
plt.gca().xaxis.set_major_formatter(date_f)

# %%
data_date=pd.read_csv(r"C:\Users\Ranjithbalan\Downloads\data (4).csv")

# %%
var=pd.to_datetime(data_date["Date"])
var1=var.sort_values()

# date.sort_values(date['Date'],inplace=True)

# %%
date_d=data_date["Date"]

close=data_date['Close']

# %%
plt.plot_date(date_d,close,linestyle="solid")
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()
